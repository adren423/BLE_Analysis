# %% [markdown]
# # Python Script for BLE Packet Analysis Graphs

# %%
'''BLE Packet analysis script for graphs developed for the experiments ran in ISR.

This script automatically performs graphs based on the evaluation metrics
present on analyzed dataframes saved on CSV files ('.csv').

Setting up:
    Make sure to mount the folder with the csv files in TEST_RESULTS/CONFIG{id}.
'''

import pyshark
import pandas as pd
import numpy as np
from collections import deque
import os

import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.ticker as ticker

# %% [markdown]
# # Graphs

# %%
# Open analyzed dataframes from config 1
analyzedf1_1 = pd.read_csv('TEST_RESULTS/CONFIG1/Config1_1_Analyzed_Data.csv')
analyzedf1_2 = pd.read_csv('TEST_RESULTS/CONFIG1/Config1_2_Analyzed_Data.csv')
analyzedf1_3 = pd.read_csv('TEST_RESULTS/CONFIG1/Config1_3_Analyzed_Data.csv')
analyzedf1_4 = pd.read_csv('TEST_RESULTS/CONFIG1/Config1_4_Analyzed_Data.csv')
analyzedf1_5 = pd.read_csv('TEST_RESULTS/CONFIG1/Config1_5_Analyzed_Data.csv')
analyzedf1_6 = pd.read_csv('TEST_RESULTS/CONFIG1/Config1_6_Analyzed_Data.csv')
analyzedf1_7 = pd.read_csv('TEST_RESULTS/CONFIG1/Config1_7_Analyzed_Data.csv')
analyzedf1_8 = pd.read_csv('TEST_RESULTS/CONFIG1/Config1_8_Analyzed_Data.csv')
analyzedf1_9 = pd.read_csv('TEST_RESULTS/CONFIG1/Config1_9_Analyzed_Data.csv')
analyzedf1_10 = pd.read_csv('TEST_RESULTS/CONFIG1/Config1_10_Analyzed_Data.csv')

# Packet Loss
pl1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl1_lst = [pl1_1, pl1_2, pl1_3, pl1_4, pl1_5, pl1_6, pl1_7, pl1_8, pl1_9, pl1_10] 
pl1_avg = np.average(pl1_lst)
box_pl1 = np.array([pl1_1, pl1_2, pl1_3, pl1_4, pl1_5, pl1_6, pl1_7, pl1_8, pl1_9, pl1_10])


# Total Test Time
time1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time1_lst = [time1_1, time1_2, time1_3, time1_4, time1_5, time1_6, time1_7, time1_8, time1_9, time1_10] 
time1_avg = np.average(time1_lst)
box_time1 = np.array([time1_1, time1_2, time1_3, time1_4, time1_5, time1_6, time1_7, time1_8, time1_9, time1_10])

# Acquisition Rate
ar_hr_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_1_lst = [ar_hr_1_1, ar_hr_1_2, ar_hr_1_3, ar_hr_1_4, ar_hr_1_5, ar_hr_1_6, ar_hr_1_7, ar_hr_1_8, ar_hr_1_9, ar_hr_1_10] 
ar_hr_1_avg = np.average(ar_hr_1_lst)

ar_t_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_1_lst = [ar_t_1_1, ar_t_1_2, ar_t_1_3, ar_t_1_4, ar_t_1_5, ar_t_1_6, ar_t_1_7, ar_t_1_8, ar_t_1_9, ar_t_1_10] 
ar_t_1_avg = np.average(ar_t_1_lst)

ar_bl_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_1_lst = [ar_bl_1_1, ar_bl_1_2, ar_bl_1_3, ar_bl_1_4, ar_bl_1_5, ar_bl_1_6, ar_bl_1_7, ar_bl_1_8, ar_bl_1_9, ar_bl_1_10] 
ar_bl_1_avg = np.average(ar_bl_1_lst)

ar_rr1_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_1_lst = [ar_rr1_1_1, ar_rr1_1_2, ar_rr1_1_3, ar_rr1_1_4, ar_rr1_1_5, ar_rr1_1_6, ar_rr1_1_7, ar_rr1_1_8, ar_rr1_1_9, ar_rr1_1_10] 
ar_rr1_1_avg = np.average(ar_rr1_1_lst)

ar_rr2_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_1_lst = [ar_rr2_1_1, ar_rr2_1_2, ar_rr2_1_3, ar_rr2_1_4, ar_rr2_1_5, ar_rr2_1_6, ar_rr2_1_7, ar_rr2_1_8, ar_rr2_1_9, ar_rr2_1_10] 
ar_rr2_1_avg = np.average(ar_rr2_1_lst)

ar_ecg_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_1_lst = [ar_ecg_1_1, ar_ecg_1_2, ar_ecg_1_3, ar_ecg_1_4, ar_ecg_1_5, ar_ecg_1_6, ar_ecg_1_7, ar_ecg_1_8, ar_ecg_1_9, ar_ecg_1_10] 
ar_ecg_1_avg = np.average(ar_ecg_1_lst)

ar_imu_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_1_lst = [ar_imu_1_1, ar_imu_1_2, ar_imu_1_3, ar_imu_1_4, ar_imu_1_5, ar_imu_1_6, ar_imu_1_7, ar_imu_1_8, ar_imu_1_9, ar_imu_1_10] 
ar_imu_1_avg = np.average(ar_imu_1_lst)

# Payload Size
ps_hr_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_1_lst = [ps_hr_1_1, ps_hr_1_2, ps_hr_1_3, ps_hr_1_4, ps_hr_1_5, ps_hr_1_6, ps_hr_1_7, ps_hr_1_8, ps_hr_1_9, ps_hr_1_10] 
ps_hr_1_avg = np.average(ps_hr_1_lst)

ps_t_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_1_lst = [ps_t_1_1, ps_t_1_2, ps_t_1_3, ps_t_1_4, ps_t_1_5, ps_t_1_6, ps_t_1_7, ps_t_1_8, ps_t_1_9, ps_t_1_10] 
ps_t_1_avg = np.average(ps_t_1_lst)

ps_bl_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_1_lst = [ps_bl_1_1, ps_bl_1_2, ps_bl_1_3, ps_bl_1_4, ps_bl_1_5, ps_bl_1_6, ps_bl_1_7, ps_bl_1_8, ps_bl_1_9, ps_bl_1_10] 
ps_bl_1_avg = np.average(ps_bl_1_lst)

ps_rr1_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_1_lst = [ps_rr1_1_1, ps_rr1_1_2, ps_rr1_1_3, ps_rr1_1_4, ps_rr1_1_5, ps_rr1_1_6, ps_rr1_1_7, ps_rr1_1_8, ps_rr1_1_9, ps_rr1_1_10] 
ps_rr1_1_avg = np.average(ps_rr1_1_lst)

ps_rr2_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_1_lst = [ps_rr2_1_1, ps_rr2_1_2, ps_rr2_1_3, ps_rr2_1_4, ps_rr2_1_5, ps_rr2_1_6, ps_rr2_1_7, ps_rr2_1_8, ps_rr2_1_9, ps_rr2_1_10] 
ps_rr2_1_avg = np.average(ps_rr2_1_lst)

ps_ecg_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_1_lst = [ps_ecg_1_1, ps_ecg_1_2, ps_ecg_1_3, ps_ecg_1_4, ps_ecg_1_5, ps_ecg_1_6, ps_ecg_1_7, ps_ecg_1_8, ps_ecg_1_9, ps_ecg_1_10] 
ps_ecg_1_avg = np.average(ps_ecg_1_lst)

ps_imu_1_1 = analyzedf1_1.loc[analyzedf1_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_1_2 = analyzedf1_2.loc[analyzedf1_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_1_3 = analyzedf1_3.loc[analyzedf1_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_1_4 = analyzedf1_4.loc[analyzedf1_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_1_5 = analyzedf1_5.loc[analyzedf1_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_1_6 = analyzedf1_6.loc[analyzedf1_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_1_7 = analyzedf1_7.loc[analyzedf1_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_1_8 = analyzedf1_8.loc[analyzedf1_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_1_9 = analyzedf1_9.loc[analyzedf1_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_1_10 = analyzedf1_10.loc[analyzedf1_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_1_lst = [ps_imu_1_1, ps_imu_1_2, ps_imu_1_3, ps_imu_1_4, ps_imu_1_5, ps_imu_1_6, ps_imu_1_7, ps_imu_1_8, ps_imu_1_9, ps_imu_1_10] 
ps_imu_1_avg = np.average(ps_imu_1_lst)



# Open analyzed dataframes from config 2
analyzedf2_1 = pd.read_csv('TEST_RESULTS/CONFIG2/Config2_1_Analyzed_Data.csv')
analyzedf2_2 = pd.read_csv('TEST_RESULTS/CONFIG2/Config2_2_Analyzed_Data.csv')
analyzedf2_3 = pd.read_csv('TEST_RESULTS/CONFIG2/Config2_3_Analyzed_Data.csv')
analyzedf2_4 = pd.read_csv('TEST_RESULTS/CONFIG2/Config2_4_Analyzed_Data.csv')
analyzedf2_5 = pd.read_csv('TEST_RESULTS/CONFIG2/Config2_5_Analyzed_Data.csv')
analyzedf2_6 = pd.read_csv('TEST_RESULTS/CONFIG2/Config2_6_Analyzed_Data.csv')
analyzedf2_7 = pd.read_csv('TEST_RESULTS/CONFIG2/Config2_7_Analyzed_Data.csv')
analyzedf2_8 = pd.read_csv('TEST_RESULTS/CONFIG2/Config2_8_Analyzed_Data.csv')
analyzedf2_9 = pd.read_csv('TEST_RESULTS/CONFIG2/Config2_9_Analyzed_Data.csv')
analyzedf2_10 = pd.read_csv('TEST_RESULTS/CONFIG2/Config2_10_Analyzed_Data.csv')

# Packet Loss
pl2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl2_lst = [pl2_1, pl2_2, pl2_3, pl2_4, pl2_5, pl2_6, pl2_7, pl2_8, pl2_9, pl2_10] 
pl2_avg = np.average(pl2_lst)
box_pl2 = np.array([pl2_1, pl2_2, pl2_3, pl2_4, pl2_5, pl2_6, pl2_7, pl2_8, pl2_9, pl2_10])


# Total test time
time2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time2_lst = [time2_1, time2_2, time2_3, time2_4, time2_5, time2_6, time2_7, time2_8, time2_9, time2_10]
time2_avg = np.average(time2_lst)
box_time2 = np.array([time2_1, time2_2, time2_3, time2_4, time2_5, time2_6, time2_7, time2_8, time2_9, time2_10])

# Acquisition Rate
ar_hr_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_2_lst = [ar_hr_2_1, ar_hr_2_2, ar_hr_2_3, ar_hr_2_4, ar_hr_2_5, ar_hr_2_6, ar_hr_2_7, ar_hr_2_8, ar_hr_2_9, ar_hr_2_10] 
ar_hr_2_avg = np.average(ar_hr_2_lst)

ar_t_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_2_lst = [ar_t_2_1, ar_t_2_2, ar_t_2_3, ar_t_2_4, ar_t_2_5, ar_t_2_6, ar_t_2_7, ar_t_2_8, ar_t_2_9, ar_t_2_10] 
ar_t_2_avg = np.average(ar_t_2_lst)

ar_bl_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_2_lst = [ar_bl_2_1, ar_bl_2_2, ar_bl_2_3, ar_bl_2_4, ar_bl_2_5, ar_bl_2_6, ar_bl_2_7, ar_bl_2_8, ar_bl_2_9, ar_bl_2_10] 
ar_bl_2_avg = np.average(ar_bl_2_lst)

ar_rr1_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_2_lst = [ar_rr1_2_1, ar_rr1_2_2, ar_rr1_2_3, ar_rr1_2_4, ar_rr1_2_5, ar_rr1_2_6, ar_rr1_2_7, ar_rr1_2_8, ar_rr1_2_9, ar_rr1_2_10] 
ar_rr1_2_avg = np.average(ar_rr1_2_lst)

ar_rr2_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_2_lst = [ar_rr2_2_1, ar_rr2_2_2, ar_rr2_2_3, ar_rr2_2_4, ar_rr2_2_5, ar_rr2_2_6, ar_rr2_2_7, ar_rr2_2_8, ar_rr2_2_9, ar_rr2_2_10] 
ar_rr2_2_avg = np.average(ar_rr2_2_lst)

ar_ecg_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_2_lst = [ar_ecg_2_1, ar_ecg_2_2, ar_ecg_2_3, ar_ecg_2_4, ar_ecg_2_5, ar_ecg_2_6, ar_ecg_2_7, ar_ecg_2_8, ar_ecg_2_9, ar_ecg_2_10] 
ar_ecg_2_avg = np.average(ar_ecg_2_lst)

ar_imu_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_2_lst = [ar_imu_2_1, ar_imu_2_2, ar_imu_2_3, ar_imu_2_4, ar_imu_2_5, ar_imu_2_6, ar_imu_2_7, ar_imu_2_8, ar_imu_2_9, ar_imu_2_10] 
ar_imu_2_avg = np.average(ar_imu_2_lst)

# Payload Size
ps_hr_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_2_lst = [ps_hr_2_1, ps_hr_2_2, ps_hr_2_3, ps_hr_2_4, ps_hr_2_5, ps_hr_2_6, ps_hr_2_7, ps_hr_2_8, ps_hr_2_9, ps_hr_2_10] 
ps_hr_2_avg = np.average(ps_hr_2_lst)

ps_t_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_2_lst = [ps_t_2_1, ps_t_2_2, ps_t_2_3, ps_t_2_4, ps_t_2_5, ps_t_2_6, ps_t_2_7, ps_t_2_8, ps_t_2_9, ps_t_2_10] 
ps_t_2_avg = np.average(ps_t_2_lst)

ps_bl_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_2_lst = [ps_bl_2_1, ps_bl_2_2, ps_bl_2_3, ps_bl_2_4, ps_bl_2_5, ps_bl_2_6, ps_bl_2_7, ps_bl_2_8, ps_bl_2_9, ps_bl_2_10] 
ps_bl_2_avg = np.average(ps_bl_2_lst)

ps_rr1_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_2_lst = [ps_rr1_2_1, ps_rr1_2_2, ps_rr1_2_3, ps_rr1_2_4, ps_rr1_2_5, ps_rr1_2_6, ps_rr1_2_7, ps_rr1_2_8, ps_rr1_2_9, ps_rr1_2_10] 
ps_rr1_2_avg = np.average(ps_rr1_2_lst)

ps_rr2_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_2_lst = [ps_rr2_2_1, ps_rr2_2_2, ps_rr2_2_3, ps_rr2_2_4, ps_rr2_2_5, ps_rr2_2_6, ps_rr2_2_7, ps_rr2_2_8, ps_rr2_2_9, ps_rr2_2_10] 
ps_rr2_2_avg = np.average(ps_rr2_2_lst)

ps_ecg_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_2_lst = [ps_ecg_2_1, ps_ecg_2_2, ps_ecg_2_3, ps_ecg_2_4, ps_ecg_2_5, ps_ecg_2_6, ps_ecg_2_7, ps_ecg_2_8, ps_ecg_2_9, ps_ecg_2_10] 
ps_ecg_2_avg = np.average(ps_ecg_2_lst)

ps_imu_2_1 = analyzedf2_1.loc[analyzedf2_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_2_2 = analyzedf2_2.loc[analyzedf2_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_2_3 = analyzedf2_3.loc[analyzedf2_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_2_4 = analyzedf2_4.loc[analyzedf2_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_2_5 = analyzedf2_5.loc[analyzedf2_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_2_6 = analyzedf2_6.loc[analyzedf2_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_2_7 = analyzedf2_7.loc[analyzedf2_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_2_8 = analyzedf2_8.loc[analyzedf2_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_2_9 = analyzedf2_9.loc[analyzedf2_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_2_10 = analyzedf2_10.loc[analyzedf2_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_2_lst = [ps_imu_2_1, ps_imu_2_2, ps_imu_2_3, ps_imu_2_4, ps_imu_2_5, ps_imu_2_6, ps_imu_2_7, ps_imu_2_8, ps_imu_2_9, ps_imu_2_10] 
ps_imu_2_avg = np.average(ps_imu_2_lst)



# Open analyzed dataframes from config 3
analyzedf3_1 = pd.read_csv('TEST_RESULTS/CONFIG3/Config3_1_Analyzed_Data.csv')
analyzedf3_2 = pd.read_csv('TEST_RESULTS/CONFIG3/Config3_2_Analyzed_Data.csv')
analyzedf3_3 = pd.read_csv('TEST_RESULTS/CONFIG3/Config3_3_Analyzed_Data.csv')
analyzedf3_4 = pd.read_csv('TEST_RESULTS/CONFIG3/Config3_4_Analyzed_Data.csv')
analyzedf3_5 = pd.read_csv('TEST_RESULTS/CONFIG3/Config3_5_Analyzed_Data.csv')
analyzedf3_6 = pd.read_csv('TEST_RESULTS/CONFIG3/Config3_6_Analyzed_Data.csv')
analyzedf3_7 = pd.read_csv('TEST_RESULTS/CONFIG3/Config3_7_Analyzed_Data.csv')
analyzedf3_8 = pd.read_csv('TEST_RESULTS/CONFIG3/Config3_8_Analyzed_Data.csv')
analyzedf3_9 = pd.read_csv('TEST_RESULTS/CONFIG3/Config3_9_Analyzed_Data.csv')
analyzedf3_10 = pd.read_csv('TEST_RESULTS/CONFIG3/Config3_10_Analyzed_Data.csv')

# Packet Loss
pl3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl3_lst = [pl3_1, pl3_2, pl3_3, pl3_4, pl3_5, pl3_6, pl3_7, pl3_8, pl3_9, pl3_10] 
pl3_avg = np.average(pl3_lst)
box_pl3 = np.array([pl3_1, pl3_2, pl3_3, pl3_4, pl3_5, pl3_6, pl3_7, pl3_8, pl3_9, pl3_10])


# Total Test Time
time3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time3_lst = [time3_1, time3_2, time3_3, time3_4, time3_5, time3_6, time3_7, time3_8, time3_9, time3_10] 
time3_avg = np.average(time3_lst)
box_time3 = np.array([time3_1, time3_2, time3_3, time3_4, time3_5, time3_6, time3_7, time3_8, time3_9, time3_10])

# Acquisition Rate
ar_hr_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_3_lst = [ar_hr_3_1, ar_hr_3_2, ar_hr_3_3, ar_hr_3_4, ar_hr_3_5, ar_hr_3_6, ar_hr_3_7, ar_hr_3_8, ar_hr_3_9, ar_hr_3_10] 
ar_hr_3_avg = np.average(ar_hr_3_lst)

ar_t_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_3_lst = [ar_t_3_1, ar_t_3_2, ar_t_3_3, ar_t_3_4, ar_t_3_5, ar_t_3_6, ar_t_3_7, ar_t_3_8, ar_t_3_9, ar_t_3_10] 
ar_t_3_avg = np.average(ar_t_3_lst)

ar_bl_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_3_lst = [ar_bl_3_1, ar_bl_3_2, ar_bl_3_3, ar_bl_3_4, ar_bl_3_5, ar_bl_3_6, ar_bl_3_7, ar_bl_3_8, ar_bl_3_9, ar_bl_3_10] 
ar_bl_3_avg = np.average(ar_bl_3_lst)

ar_rr1_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_3_lst = [ar_rr1_3_1, ar_rr1_3_2, ar_rr1_3_3, ar_rr1_3_4, ar_rr1_3_5, ar_rr1_3_6, ar_rr1_3_7, ar_rr1_3_8, ar_rr1_3_9, ar_rr1_3_10] 
ar_rr1_3_avg = np.average(ar_rr1_3_lst)

ar_rr2_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_3_lst = [ar_rr2_3_1, ar_rr2_3_2, ar_rr2_3_3, ar_rr2_3_4, ar_rr2_3_5, ar_rr2_3_6, ar_rr2_3_7, ar_rr2_3_8, ar_rr2_3_9, ar_rr2_3_10] 
ar_rr2_3_avg = np.average(ar_rr2_3_lst)

ar_ecg_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_3_lst = [ar_ecg_3_1, ar_ecg_3_2, ar_ecg_3_3, ar_ecg_3_4, ar_ecg_3_5, ar_ecg_3_6, ar_ecg_3_7, ar_ecg_3_8, ar_ecg_3_9, ar_ecg_3_10] 
ar_ecg_3_avg = np.average(ar_ecg_3_lst)

ar_imu_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_3_lst = [ar_imu_3_1, ar_imu_3_2, ar_imu_3_3, ar_imu_3_4, ar_imu_3_5, ar_imu_3_6, ar_imu_3_7, ar_imu_3_8, ar_imu_3_9, ar_imu_3_10] 
ar_imu_3_avg = np.average(ar_imu_3_lst)

# Payload Size
ps_hr_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_3_lst = [ps_hr_3_1, ps_hr_3_2, ps_hr_3_3, ps_hr_3_4, ps_hr_3_5, ps_hr_3_6, ps_hr_3_7, ps_hr_3_8, ps_hr_3_9, ps_hr_3_10] 
ps_hr_3_avg = np.average(ps_hr_3_lst)

ps_t_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_3_lst = [ps_t_3_1, ps_t_3_2, ps_t_3_3, ps_t_3_4, ps_t_3_5, ps_t_3_6, ps_t_3_7, ps_t_3_8, ps_t_3_9, ps_t_3_10] 
ps_t_3_avg = np.average(ps_t_3_lst)

ps_bl_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_3_lst = [ps_bl_3_1, ps_bl_3_2, ps_bl_3_3, ps_bl_3_4, ps_bl_3_5, ps_bl_3_6, ps_bl_3_7, ps_bl_3_8, ps_bl_3_9, ps_bl_3_10] 
ps_bl_3_avg = np.average(ps_bl_3_lst)

ps_rr1_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_3_lst = [ps_rr1_3_1, ps_rr1_3_2, ps_rr1_3_3, ps_rr1_3_4, ps_rr1_3_5, ps_rr1_3_6, ps_rr1_3_7, ps_rr1_3_8, ps_rr1_3_9, ps_rr1_3_10] 
ps_rr1_3_avg = np.average(ps_rr1_3_lst)

ps_rr2_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_3_lst = [ps_rr2_3_1, ps_rr2_3_2, ps_rr2_3_3, ps_rr2_3_4, ps_rr2_3_5, ps_rr2_3_6, ps_rr2_3_7, ps_rr2_3_8, ps_rr2_3_9, ps_rr2_3_10] 
ps_rr2_3_avg = np.average(ps_rr2_3_lst)

ps_ecg_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_3_lst = [ps_ecg_3_1, ps_ecg_3_2, ps_ecg_3_3, ps_ecg_3_4, ps_ecg_3_5, ps_ecg_3_6, ps_ecg_3_7, ps_ecg_3_8, ps_ecg_3_9, ps_ecg_3_10] 
ps_ecg_3_avg = np.average(ps_ecg_3_lst)

ps_imu_3_1 = analyzedf3_1.loc[analyzedf3_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_3_2 = analyzedf3_2.loc[analyzedf3_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_3_3 = analyzedf3_3.loc[analyzedf3_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_3_4 = analyzedf3_4.loc[analyzedf3_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_3_5 = analyzedf3_5.loc[analyzedf3_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_3_6 = analyzedf3_6.loc[analyzedf3_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_3_7 = analyzedf3_7.loc[analyzedf3_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_3_8 = analyzedf3_8.loc[analyzedf3_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_3_9 = analyzedf3_9.loc[analyzedf3_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_3_10 = analyzedf3_10.loc[analyzedf3_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_3_lst = [ps_imu_3_1, ps_imu_3_2, ps_imu_3_3, ps_imu_3_4, ps_imu_3_5, ps_imu_3_6, ps_imu_3_7, ps_imu_3_8, ps_imu_3_9, ps_imu_3_10] 
ps_imu_3_avg = np.average(ps_imu_3_lst)




# Open analyzed dataframes from config 4
analyzedf4_1 = pd.read_csv('TEST_RESULTS/CONFIG4/Config4_1_Analyzed_Data.csv')
analyzedf4_2 = pd.read_csv('TEST_RESULTS/CONFIG4/Config4_2_Analyzed_Data.csv')
analyzedf4_3 = pd.read_csv('TEST_RESULTS/CONFIG4/Config4_3_Analyzed_Data.csv')
analyzedf4_4 = pd.read_csv('TEST_RESULTS/CONFIG4/Config4_4_Analyzed_Data.csv')
analyzedf4_5 = pd.read_csv('TEST_RESULTS/CONFIG4/Config4_5_Analyzed_Data.csv')
analyzedf4_6 = pd.read_csv('TEST_RESULTS/CONFIG4/Config4_6_Analyzed_Data.csv')
analyzedf4_7 = pd.read_csv('TEST_RESULTS/CONFIG4/Config4_7_Analyzed_Data.csv')
analyzedf4_8 = pd.read_csv('TEST_RESULTS/CONFIG4/Config4_8_Analyzed_Data.csv')
analyzedf4_9 = pd.read_csv('TEST_RESULTS/CONFIG4/Config4_9_Analyzed_Data.csv')
analyzedf4_10 = pd.read_csv('TEST_RESULTS/CONFIG4/Config4_10_Analyzed_Data.csv')

# Packet Loss
pl4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl4_lst = [pl4_1, pl4_2, pl4_3, pl4_4, pl4_5, pl4_6, pl4_7, pl4_8, pl4_9, pl4_10] 
pl4_avg = np.average(pl4_lst)
box_pl4 = np.array([pl4_1, pl4_2, pl4_3, pl4_4, pl4_5, pl4_6, pl4_7, pl4_8, pl4_9, pl4_10])


# Total Test Time
time4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time4_lst = [time4_1, time4_2, time4_3, time4_4, time4_5, time4_6, time4_7, time4_8, time4_9, time4_10] 
time4_avg = np.average(time4_lst)
box_time4 = np.array([time4_1, time4_2, time4_3, time4_4, time4_5, time4_6, time4_7, time4_8, time4_9, time4_10])

# Acquisition Rate
ar_hr_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_4_lst = [ar_hr_4_1, ar_hr_4_2, ar_hr_4_3, ar_hr_4_4, ar_hr_4_5, ar_hr_4_6, ar_hr_4_7, ar_hr_4_8, ar_hr_4_9, ar_hr_4_10] 
ar_hr_4_avg = np.average(ar_hr_4_lst)

ar_t_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_4_lst = [ar_t_4_1, ar_t_4_2, ar_t_4_3, ar_t_4_4, ar_t_4_5, ar_t_4_6, ar_t_4_7, ar_t_4_8, ar_t_4_9, ar_t_4_10] 
ar_t_4_avg = np.average(ar_t_4_lst)

ar_bl_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_4_lst = [ar_bl_4_1, ar_bl_4_2, ar_bl_4_3, ar_bl_4_4, ar_bl_4_5, ar_bl_4_6, ar_bl_4_7, ar_bl_4_8, ar_bl_4_9, ar_bl_4_10] 
ar_bl_4_avg = np.average(ar_bl_4_lst)

ar_rr1_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_4_lst = [ar_rr1_4_1, ar_rr1_4_2, ar_rr1_4_3, ar_rr1_4_4, ar_rr1_4_5, ar_rr1_4_6, ar_rr1_4_7, ar_rr1_4_8, ar_rr1_4_9, ar_rr1_4_10] 
ar_rr1_4_avg = np.average(ar_rr1_4_lst)

ar_rr2_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_4_lst = [ar_rr2_4_1, ar_rr2_4_2, ar_rr2_4_3, ar_rr2_4_4, ar_rr2_4_5, ar_rr2_4_6, ar_rr2_4_7, ar_rr2_4_8, ar_rr2_4_9, ar_rr2_4_10] 
ar_rr2_4_avg = np.average(ar_rr2_4_lst)

ar_ecg_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_4_lst = [ar_ecg_4_1, ar_ecg_4_2, ar_ecg_4_3, ar_ecg_4_4, ar_ecg_4_5, ar_ecg_4_6, ar_ecg_4_7, ar_ecg_4_8, ar_ecg_4_9, ar_ecg_4_10] 
ar_ecg_4_avg = np.average(ar_ecg_4_lst)

ar_imu_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_4_lst = [ar_imu_4_1, ar_imu_4_2, ar_imu_4_3, ar_imu_4_4, ar_imu_4_5, ar_imu_4_6, ar_imu_4_7, ar_imu_4_8, ar_imu_4_9, ar_imu_4_10] 
ar_imu_4_avg = np.average(ar_imu_4_lst)

# Payload Size
ps_hr_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_4_lst = [ps_hr_4_1, ps_hr_4_2, ps_hr_4_3, ps_hr_4_4, ps_hr_4_5, ps_hr_4_6, ps_hr_4_7, ps_hr_4_8, ps_hr_4_9, ps_hr_4_10] 
ps_hr_4_avg = np.average(ps_hr_4_lst)

ps_t_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_4_lst = [ps_t_4_1, ps_t_4_2, ps_t_4_3, ps_t_4_4, ps_t_4_5, ps_t_4_6, ps_t_4_7, ps_t_4_8, ps_t_4_9, ps_t_4_10] 
ps_t_4_avg = np.average(ps_t_4_lst)

ps_bl_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_4_lst = [ps_bl_4_1, ps_bl_4_2, ps_bl_4_3, ps_bl_4_4, ps_bl_4_5, ps_bl_4_6, ps_bl_4_7, ps_bl_4_8, ps_bl_4_9, ps_bl_4_10] 
ps_bl_4_avg = np.average(ps_bl_4_lst)

ps_rr1_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_4_lst = [ps_rr1_4_1, ps_rr1_4_2, ps_rr1_4_3, ps_rr1_4_4, ps_rr1_4_5, ps_rr1_4_6, ps_rr1_4_7, ps_rr1_4_8, ps_rr1_4_9, ps_rr1_4_10] 
ps_rr1_4_avg = np.average(ps_rr1_4_lst)

ps_rr2_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_4_lst = [ps_rr2_4_1, ps_rr2_4_2, ps_rr2_4_3, ps_rr2_4_4, ps_rr2_4_5, ps_rr2_4_6, ps_rr2_4_7, ps_rr2_4_8, ps_rr2_4_9, ps_rr2_4_10] 
ps_rr2_4_avg = np.average(ps_rr2_4_lst)

ps_ecg_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_4_lst = [ps_ecg_4_1, ps_ecg_4_2, ps_ecg_4_3, ps_ecg_4_4, ps_ecg_4_5, ps_ecg_4_6, ps_ecg_4_7, ps_ecg_4_8, ps_ecg_4_9, ps_ecg_4_10] 
ps_ecg_4_avg = np.average(ps_ecg_4_lst)

ps_imu_4_1 = analyzedf4_1.loc[analyzedf4_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_4_2 = analyzedf4_2.loc[analyzedf4_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_4_3 = analyzedf4_3.loc[analyzedf4_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_4_4 = analyzedf4_4.loc[analyzedf4_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_4_5 = analyzedf4_5.loc[analyzedf4_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_4_6 = analyzedf4_6.loc[analyzedf4_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_4_7 = analyzedf4_7.loc[analyzedf4_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_4_8 = analyzedf4_8.loc[analyzedf4_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_4_9 = analyzedf4_9.loc[analyzedf4_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_4_10 = analyzedf4_10.loc[analyzedf4_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_4_lst = [ps_imu_4_1, ps_imu_4_2, ps_imu_4_3, ps_imu_4_4, ps_imu_4_5, ps_imu_4_6, ps_imu_4_7, ps_imu_4_8, ps_imu_4_9, ps_imu_4_10] 
ps_imu_4_avg = np.average(ps_imu_4_lst)



# Open analyzed dataframes from config 5
analyzedf5_1 = pd.read_csv('TEST_RESULTS/CONFIG5/Config5_1_Analyzed_Data.csv')
analyzedf5_2 = pd.read_csv('TEST_RESULTS/CONFIG5/Config5_2_Analyzed_Data.csv')
analyzedf5_3 = pd.read_csv('TEST_RESULTS/CONFIG5/Config5_3_Analyzed_Data.csv')
analyzedf5_4 = pd.read_csv('TEST_RESULTS/CONFIG5/Config5_4_Analyzed_Data.csv')
analyzedf5_5 = pd.read_csv('TEST_RESULTS/CONFIG5/Config5_5_Analyzed_Data.csv')
analyzedf5_6 = pd.read_csv('TEST_RESULTS/CONFIG5/Config5_6_Analyzed_Data.csv')
analyzedf5_7 = pd.read_csv('TEST_RESULTS/CONFIG5/Config5_7_Analyzed_Data.csv')
analyzedf5_8 = pd.read_csv('TEST_RESULTS/CONFIG5/Config5_8_Analyzed_Data.csv')
analyzedf5_9 = pd.read_csv('TEST_RESULTS/CONFIG5/Config5_9_Analyzed_Data.csv')
analyzedf5_10 = pd.read_csv('TEST_RESULTS/CONFIG5/Config5_10_Analyzed_Data.csv')

# Packet Loss
pl5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST PACKET LOSS'].values
pl5_lst = [pl5_1, pl5_2, pl5_3, pl5_4, pl5_5, pl5_6, pl5_7, pl5_8, pl5_9, pl5_10] 
pl5_avg = np.average(pl5_lst)
box_pl5 = np.array([pl5_1, pl5_2, pl5_3, pl5_4, pl5_5, pl5_6, pl5_7, pl5_8, pl5_9, pl5_10])


# Total Test Time
time5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'TOTAL TEST TIME'].values
time5_lst = [time5_1, time5_2, time5_3, time5_4, time5_5, time5_6, time5_7, time5_8, time5_9, time5_10] 
time5_avg = np.average(time5_lst)
box_time5 = np.array([time5_1, time5_2, time5_3, time5_4, time5_5, time5_6, time5_7, time5_8, time5_9, time5_10])

# Acquisition Rate
ar_hr_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'ACQUISITION RATE'].values
ar_hr_5_lst = [ar_hr_5_1, ar_hr_5_2, ar_hr_5_3, ar_hr_5_4, ar_hr_5_5, ar_hr_5_6, ar_hr_5_7, ar_hr_5_8, ar_hr_5_9, ar_hr_5_10] 
ar_hr_5_avg = np.average(ar_hr_5_lst)

ar_t_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'ACQUISITION RATE'].values
ar_t_5_lst = [ar_t_5_1, ar_t_5_2, ar_t_5_3, ar_t_5_4, ar_t_5_5, ar_t_5_6, ar_t_5_7, ar_t_5_8, ar_t_5_9, ar_t_5_10] 
ar_t_5_avg = np.average(ar_t_5_lst)

ar_bl_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'ACQUISITION RATE'].values
ar_bl_5_lst = [ar_bl_5_1, ar_bl_5_2, ar_bl_5_3, ar_bl_5_4, ar_bl_5_5, ar_bl_5_6, ar_bl_5_7, ar_bl_5_8, ar_bl_5_9, ar_bl_5_10] 
ar_bl_5_avg = np.average(ar_bl_5_lst)

ar_rr1_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'ACQUISITION RATE'].values
ar_rr1_5_lst = [ar_rr1_5_1, ar_rr1_5_2, ar_rr1_5_3, ar_rr1_5_4, ar_rr1_5_5, ar_rr1_5_6, ar_rr1_5_7, ar_rr1_5_8, ar_rr1_5_9, ar_rr1_5_10] 
ar_rr1_5_avg = np.average(ar_rr1_5_lst)

ar_rr2_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'ACQUISITION RATE'].values
ar_rr2_5_lst = [ar_rr2_5_1, ar_rr2_5_2, ar_rr2_5_3, ar_rr2_5_4, ar_rr2_5_5, ar_rr2_5_6, ar_rr2_5_7, ar_rr2_5_8, ar_rr2_5_9, ar_rr2_5_10] 
ar_rr2_5_avg = np.average(ar_rr2_5_lst)

ar_ecg_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'ACQUISITION RATE'].values
ar_ecg_5_lst = [ar_ecg_5_1, ar_ecg_5_2, ar_ecg_5_3, ar_ecg_5_4, ar_ecg_5_5, ar_ecg_5_6, ar_ecg_5_7, ar_ecg_5_8, ar_ecg_5_9, ar_ecg_5_10] 
ar_ecg_5_avg = np.average(ar_ecg_5_lst)

ar_imu_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'ACQUISITION RATE'].values
ar_imu_5_lst = [ar_imu_5_1, ar_imu_5_2, ar_imu_5_3, ar_imu_5_4, ar_imu_5_5, ar_imu_5_6, ar_imu_5_7, ar_imu_5_8, ar_imu_5_9, ar_imu_5_10] 
ar_imu_5_avg = np.average(ar_imu_5_lst)

# Payload Size
ps_hr_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a37'", 'MEAN PAYLOAD SIZE'].values
ps_hr_5_lst = [ps_hr_5_1, ps_hr_5_2, ps_hr_5_3, ps_hr_5_4, ps_hr_5_5, ps_hr_5_6, ps_hr_5_7, ps_hr_5_8, ps_hr_5_9, ps_hr_5_10] 
ps_hr_5_avg = np.average(ps_hr_5_lst)

ps_t_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a1c'", 'MEAN PAYLOAD SIZE'].values
ps_t_5_lst = [ps_t_5_1, ps_t_5_2, ps_t_5_3, ps_t_5_4, ps_t_5_5, ps_t_5_6, ps_t_5_7, ps_t_5_8, ps_t_5_9, ps_t_5_10] 
ps_t_5_avg = np.average(ps_t_5_lst)

ps_bl_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0x2a19'", 'MEAN PAYLOAD SIZE'].values
ps_bl_5_lst = [ps_bl_5_1, ps_bl_5_2, ps_bl_5_3, ps_bl_5_4, ps_bl_5_5, ps_bl_5_6, ps_bl_5_7, ps_bl_5_8, ps_bl_5_9, ps_bl_5_10] 
ps_bl_5_avg = np.average(ps_bl_5_lst)

ps_rr1_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa002'", 'MEAN PAYLOAD SIZE'].values
ps_rr1_5_lst = [ps_rr1_5_1, ps_rr1_5_2, ps_rr1_5_3, ps_rr1_5_4, ps_rr1_5_5, ps_rr1_5_6, ps_rr1_5_7, ps_rr1_5_8, ps_rr1_5_9, ps_rr1_5_10] 
ps_rr1_5_avg = np.average(ps_rr1_5_lst)

ps_rr2_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa008'", 'MEAN PAYLOAD SIZE'].values
ps_rr2_5_lst = [ps_rr2_5_1, ps_rr2_5_2, ps_rr2_5_3, ps_rr2_5_4, ps_rr2_5_5, ps_rr2_5_6, ps_rr2_5_7, ps_rr2_5_8, ps_rr2_5_9, ps_rr2_5_10] 
ps_rr2_5_avg = np.average(ps_rr2_5_lst)

ps_ecg_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa003'", 'MEAN PAYLOAD SIZE'].values
ps_ecg_5_lst = [ps_ecg_5_1, ps_ecg_5_2, ps_ecg_5_3, ps_ecg_5_4, ps_ecg_5_5, ps_ecg_5_6, ps_ecg_5_7, ps_ecg_5_8, ps_ecg_5_9, ps_ecg_5_10] 
ps_ecg_5_avg = np.average(ps_ecg_5_lst)

ps_imu_5_1 = analyzedf5_1.loc[analyzedf5_1['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_5_2 = analyzedf5_2.loc[analyzedf5_2['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_5_3 = analyzedf5_3.loc[analyzedf5_3['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_5_4 = analyzedf5_4.loc[analyzedf5_4['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_5_5 = analyzedf5_5.loc[analyzedf5_5['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_5_6 = analyzedf5_6.loc[analyzedf5_6['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_5_7 = analyzedf5_7.loc[analyzedf5_7['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_5_8 = analyzedf5_8.loc[analyzedf5_8['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_5_9 = analyzedf5_9.loc[analyzedf5_9['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_5_10 = analyzedf5_10.loc[analyzedf5_10['CHARACTERISTIC UUID'].astype(str) == "b'0xa004'", 'MEAN PAYLOAD SIZE'].values
ps_imu_5_lst = [ps_imu_5_1, ps_imu_5_2, ps_imu_5_3, ps_imu_5_4, ps_imu_5_5, ps_imu_5_6, ps_imu_5_7, ps_imu_5_8, ps_imu_5_9, ps_imu_5_10] 
ps_imu_5_avg = np.average(ps_imu_5_lst)




# GRAPHS

# GRAPH TOTAL TEST PACKET LOSS (%) AND ALL CONFIGS
x1 = ['NoSec-RPi', 'LE-JW-S', 'LE-JW-RPi', 'LE-OOB-S', 'LE-OOB-nRF']
y1 = [pl1_avg, pl2_avg, pl3_avg, pl4_avg, pl5_avg]
fig, ax = plt.subplots()
ax.grid(True, color='gainsboro', linewidth=0.1)  # Add grid lines
ax.set_axisbelow(True)
ax.scatter(x1, y1, color='g')
plt.ylim(-0.1, 2.7)
plt.xlabel('Configurações', labelpad=10)
plt.ylabel('Perda Média de Pacotes (%)', labelpad=10)
#plt.savefig("TEST_RESULTS/PacketLoss.pdf", format="pdf", bbox_inches="tight")
# Print the chart
#plt.show()


# BOX PLOT WITH TOTAL TEST PACKET LOSS (%) AND ALL CONFIGS
x1 = ['NoSec-RPi', 'LE-JW-S', 'LE-JW-RPi', 'LE-OOB-S', 'LE-OOB-nRF']
fig, ax = plt.subplots(figsize=(8, 5))
ax.yaxis.grid(True, color='gainsboro', linewidth=0.1)  # Add grid lines
ax.set_axisbelow(True)
meanpointprops = dict(marker='x', markeredgecolor='black', markerfacecolor='white', markersize=7)
data = [box_pl1.flatten(), box_pl2.flatten(), box_pl3.flatten(), box_pl4.flatten(), box_pl5.flatten()]
ax.boxplot(data, vert=True, patch_artist=True, labels=x1, showmeans=True, meanprops=meanpointprops) # showfliers = False
plt.ylim(-0.1, 4.5)
plt.xlabel('Configurações', labelpad=10)
plt.ylabel('Perda de Pacotes (%)', labelpad=10)
plt.savefig("TEST_RESULTS/BoxPacketLoss.pdf", format="pdf", bbox_inches="tight")
plt.savefig("TEST_RESULTS/BoxPacketLoss1.svg", format="svg", bbox_inches="tight")
plt.show()


# GRAPH TOTAL TEST TIME (s) AND ALL CONFIGS
x1 = ['NoSec-RPi', 'LE-JW-S', 'LE-JW-RPi', 'LE-OOB-S', 'LE-OOB-nRF']
y1 = [time1_avg, time2_avg, time3_avg, time4_avg, time5_avg]
fig, ax = plt.subplots()
ax.grid(True, color='gainsboro', linewidth=0.1)  # Add grid lines
ax.set_axisbelow(True)
ax.scatter(x1, y1, color='b')
plt.ylim(100, 150)
plt.xlabel('Configurações', labelpad=10)
plt.ylabel('Tempo Total Médio de Teste (s)', labelpad=10)
#plt.savefig("TEST_RESULTS/TotalTestTime.pdf", format="pdf", bbox_inches="tight")
# Print the chart
#plt.show()


# BOX PLOT WITH TOTAL TEST TIME (s) AND ALL CONFIGS
x1 = ['NoSec-RPi', 'LE-JW-S', 'LE-JW-RPi', 'LE-OOB-S', 'LE-OOB-nRF']
fig, ax = plt.subplots(figsize=(8, 5))
ax.yaxis.grid(True, color='gainsboro', linewidth=0.1)  # Add grid lines
ax.set_axisbelow(True)
meanpointprops = dict(marker='x', markeredgecolor='black', markerfacecolor='white', markersize=7)
data = [box_time1.flatten(), box_time2.flatten(), box_time3.flatten(), box_time4.flatten(), box_time5.flatten()]
ax.boxplot(data, vert=True, patch_artist=True, labels=x1, showmeans=True, meanprops=meanpointprops) # showfliers = False
plt.ylim(110, 135)
plt.xlabel('Configurações', labelpad=10)
plt.ylabel('Tempo Total de Teste (s)', labelpad=10)
plt.savefig("TEST_RESULTS/BoxTotalTestTime.pdf", format="pdf", bbox_inches="tight")
plt.savefig("TEST_RESULTS/BoxTotalTestTime1.svg", format="svg", bbox_inches="tight")
plt.show()


# ACQUISITION RATE (Hz) PER CHARACTERISTIC IN ALL CONFIGS
x1 = ['Frequência\nCardíaca', 'Temperatura', 'Nível de\nBateria', 'Resp1', 'Resp2', 'ECG', 'IMU']
y1 = [ar_hr_1_avg, ar_t_1_avg, ar_bl_1_avg, ar_rr1_1_avg, ar_rr2_1_avg, ar_ecg_1_avg, ar_imu_1_avg]
y2 = [ar_hr_2_avg, ar_t_2_avg, ar_bl_2_avg, ar_rr1_2_avg, ar_rr2_2_avg, ar_ecg_2_avg, ar_imu_2_avg]
y3 = [ar_hr_3_avg, ar_t_3_avg, ar_bl_3_avg, ar_rr1_3_avg, ar_rr2_3_avg, ar_ecg_3_avg, ar_imu_3_avg]
y4 = [ar_hr_4_avg, ar_t_4_avg, ar_bl_4_avg, ar_rr1_4_avg, ar_rr2_4_avg, ar_ecg_4_avg, ar_imu_4_avg]
y5 = [ar_hr_5_avg, ar_t_5_avg, ar_bl_5_avg, ar_rr1_5_avg, ar_rr2_5_avg, ar_ecg_5_avg, ar_imu_5_avg]
y6 = [0.2, 0.01666666666, 0.1, 10, 10, 4, 20]
fig, ax = plt.subplots(figsize=(8, 5))
ax.grid(True, color='gainsboro', linewidth=0.1)  # Add grid lines
ax.set_axisbelow(True)
ax.scatter(x1, y1, color='r', label='NoSec-RPi') # s=50
ax.scatter(x1, y2, color='b', label='LE-JW-S') # s=40
ax.scatter(x1, y3, color='g', label='LE-JW-RPi') # s=30
ax.scatter(x1, y4, color='m', label='LE-OOB-S') # s=20
ax.scatter(x1, y5, color='y', label='LE-OOB-nRF') # s=10
ax.scatter(x1, y6, color='c', label='Valor Esperado')
plt.ylim(-1, 21)
plt.xlabel('Características', labelpad=10)
plt.ylabel('Taxa Média de Aquisição (Hz)', labelpad=10)
plt.legend(loc='upper left')
plt.savefig("TEST_RESULTS/AcquisitionRate.pdf", format="pdf", bbox_inches="tight")
plt.savefig("TEST_RESULTS/AcquisitionRate1.svg", format="svg", bbox_inches="tight")
# Print the chart
plt.show()


# PAYLOAD SIZE (bytes) PER CHARACTERISTIC IN ALL CONFIGS
x1 = ['Frequência\nCardíaca', 'Temperatura', 'Nível de\nBateria', 'Resp1', 'Resp2', 'ECG', 'IMU']
y1 = [ps_hr_1_avg, ps_t_1_avg, ps_bl_1_avg, ps_rr1_1_avg, ps_rr2_1_avg, ps_ecg_1_avg, ps_imu_1_avg]
y2 = [ps_hr_2_avg, ps_t_2_avg, ps_bl_2_avg, ps_rr1_2_avg, ps_rr2_2_avg, ps_ecg_2_avg, ps_imu_2_avg]
y3 = [ps_hr_3_avg, ps_t_3_avg, ps_bl_3_avg, ps_rr1_3_avg, ps_rr2_3_avg, ps_ecg_3_avg, ps_imu_3_avg]
y4 = [ps_hr_4_avg, ps_t_4_avg, ps_bl_4_avg, ps_rr1_4_avg, ps_rr2_4_avg, ps_ecg_4_avg, ps_imu_4_avg]
y5 = [ps_hr_5_avg, ps_t_5_avg, ps_bl_5_avg, ps_rr1_5_avg, ps_rr2_5_avg, ps_ecg_5_avg, ps_imu_5_avg]
fig, ax = plt.subplots(figsize=(8, 5))
ax.grid(True, color='gainsboro', linewidth=0.1)  # Add grid lines
ax.set_axisbelow(True)
ax.scatter(x1, y1, color='r', label='NoSec-RPi') # s=50
ax.scatter(x1, y2, color='b', label='LE-JW-S') # s=40
ax.scatter(x1, y3, color='g', label='LE-JW-RPi') # s=30
ax.scatter(x1, y4, color='m', label='LE-OOB-S') # s=20
ax.scatter(x1, y5, color='y', label='LE-OOB-nRF') # s=10
plt.ylim(4, 20)
plt.xlabel('Características', labelpad=10)
plt.ylabel('Tamanho Médio do Payload (bytes)', labelpad=10)
plt.legend(loc='upper left')
plt.savefig("TEST_RESULTS/PayloadSize.pdf", format="pdf", bbox_inches="tight")
plt.savefig("TEST_RESULTS/PayloadSize1.svg", format="svg", bbox_inches="tight")
# Print the chart
plt.show()

# %%
print(ar_hr_1_avg)
print(ar_hr_2_avg)
print(ar_hr_3_avg)
print(ar_hr_4_avg)
print(ar_hr_5_avg)
# Out:
# 0.19608053139609138
# 0.1771639797354017
# 0.19626771186192002
# 0.17622235034270822
# 0.19380693514052266

# %%
print(ar_t_1_avg)
print(ar_t_2_avg)
print(ar_t_3_avg)
print(ar_t_4_avg)
print(ar_t_5_avg)
# Out:
# 0.01742939624969285
# 0.01574713491940079
# 0.017368771160492995
# 0.015595142608644192
# 0.017381777964971548

# %%
print(ar_bl_1_avg)
print(ar_bl_2_avg)
print(ar_bl_3_avg)
print(ar_bl_4_avg)
print(ar_bl_5_avg)
# Out:
# 0.0958616793733108
# 0.08976236583489765
# 0.0972663227797319
# 0.08732941846991533
# 0.09386190035609106

# %%
ps_hr = [ps_hr_1_avg, ps_hr_2_avg, ps_hr_3_avg, ps_hr_4_avg, ps_hr_5_avg] 
ps_hr_desvio = np.max(ps_hr)-np.min(ps_hr)
print(ps_hr_desvio)

ps_t = [ps_t_1_avg, ps_t_2_avg, ps_t_3_avg, ps_t_4_avg, ps_t_5_avg] 
ps_t_desvio = np.max(ps_t)-np.min(ps_t)
print(ps_t_desvio)

ps_bl = [ps_bl_1_avg, ps_bl_2_avg, ps_bl_3_avg, ps_bl_4_avg, ps_bl_5_avg] 
ps_bl_desvio = np.max(ps_bl)-np.min(ps_bl)
print(ps_bl_desvio)

ps_rr1 = [ps_rr1_1_avg, ps_rr1_2_avg, ps_rr1_3_avg, ps_rr1_4_avg, ps_rr1_5_avg] 
ps_rr1_desvio = np.max(ps_rr1)-np.min(ps_rr1)
print(ps_rr1_desvio)

ps_rr2 = [ps_rr2_1_avg, ps_rr2_2_avg, ps_rr2_3_avg, ps_rr2_4_avg, ps_rr2_5_avg] 
ps_rr2_desvio = np.max(ps_rr2)-np.min(ps_rr2)
print(ps_rr2_desvio)

ps_ecg = [ps_ecg_1_avg, ps_ecg_2_avg, ps_ecg_3_avg, ps_ecg_4_avg, ps_ecg_5_avg] 
ps_ecg_desvio = np.max(ps_ecg)-np.min(ps_ecg)
print(ps_ecg_desvio)

ps_imu = [ps_imu_1_avg, ps_imu_2_avg, ps_imu_3_avg, ps_imu_4_avg, ps_imu_5_avg] 
ps_imu_desvio = np.max(ps_imu)-np.min(ps_imu)
print(ps_imu_desvio)
# Out:
# 0.0
# 0.0
# 0.0
# 0.011393024814498887
# 0.0
# 0.0
# 0.009436493738819607
